# %%
library(twitteR)

consumer_key <- "d9q3JVpPEOhb7pLqlP3Tn7LBw"
consumer_secret <- "aTZj72mUPrUvZHOofDzOAMp8Ro1FVwHNzEKPZA4H3kww13RhKJ"
access_token <- "960608039458963456-Zt65NRJyDL4ws97zsOND8lPpLdXweL8"
access_secret <- "KjFj1n7HryIxm4MmjuF3df5hNXmmT1vecqZGokYfPWkMV"
options(httr_oauth_cache=T)
setup_twitter_oauth(consumer_key, consumer_secret, access_token, access_secret)
tweets <- searchTwitter('#rstats', n=50)
head(tweets)
# Out:
# [1] "Using direct authentication"
# [[1]]
# [1] "brennanpcardiff: RT @DynamicWebPaige: The #rstats community is obsessed with:\n\n- straightforward documentation\n- effective communication\n- data visualizatio…"
#
# [[2]]
# [1] "brennanpcardiff: RT @hadleywickham: I've hung out with the data scientists at the BOE and I can highly recommend this opportunity! #rstats https://t.co/oZLA…"
#
# [[3]]
# [1] "R_Graph_Gallery: A representation of multiple GWAS results using #rstats and circos https://t.co/Ns9Wg646f3"
#
# [[4]]
# [1] "NinjaLinker: RT @CedricGuerin: J'y étais hier et je recommande !!\nLa data c'est l'avenir pour le SEO !!\nhttps://t.co/S3jBEYxkNX\n#SEO #python #Rstats\nMer…"
#
# [[5]]
# [1] "MangoTheCat: RT @Rbloggers: Love Machine: Automating the romantic songwriting process https://t.co/aiu49uI20I #rstats #DataScience"
#
# [[6]]
# [1] "brennanpcardiff: RT @R_Forwards: New blog post on initiatives in the #rstats community in Africa https://t.co/cbtI5NcUgU"

# %%
head(strip_retweets(tweets, strip_manual=TRUE, strip_mt=TRUE))
# Out:
# [[1]]
# [1] "R_Graph_Gallery: A representation of multiple GWAS results using #rstats and circos https://t.co/Ns9Wg646f3"
#
# [[2]]
# [1] "tipsder: Algunos comando básicos de #R.\nhttps://t.co/iQg1GZGMdh\n#rstats \n#DataScience \n#dataviz \n#Datavisualization"
#
# [[3]]
# [1] "westgatecology: New #rstats package: revtools - bibliographic data visualization for evidence synthesis projects inc.… https://t.co/xrCfJsSQEb"
#
# [[4]]
# [1] "CRANberriesFeed: CRAN updates: wallace https://t.co/y5W2NTKSXT #rstats"
#
# [[5]]
# [1] "mdneuzerling: I learned that \"grepl\" means \"grep logical\", not \"grep list\". This would be less embarrassing if I hadn't been using grepl for years #rstats"
#
# [[6]]
# [1] "jasdumas: \xed\xa0\xbd\xed\xb1\x8fThanks to @jonmcalder for this PR to #shinyLP #rstats https://t.co/u4rhIRsd1D"

# %%
crantastic <- getUser('crantastic')
crantastic$getDescription()
crantastic$getFollowersCount()
crantastic$getFriends(n=5)
crantastic$getFavorites(n=5)
# Out:
# [1] "I like some things, and I dislike everything else."
# [1] 29
# $`125217894`
# [1] "VirginiaGardner"
#
# $`35985504`
# [1] "MisElizaJane"
#
# $`90472293`
# [1] "emtothea"
# [[1]]
# [1] "mariootsa: @kumailn Maybe some day SNL will allow online videos of their show to be seen in Canada."
#
# [[2]]
# [1] "erictcarrasco: That \"Black lung\" line was a @Chy_Leigh joke. Loved it so much we made her keep saying it. #Supergirl #SupergirlLives #Sanvers"
#
# [[3]]
# [1] "MelanieScrofano: I shall be INSUFFERABLE when the @WynonnaEarp comic I'm co-writing with @BeauSmithRanch comes out. \"The Earp Sister… https://t.co/h0Q6XrE1dV"
#
# [[4]]
# [1] "katevoegele: just casually throwing my white gold hoops in the ring to play #GretchenWieners in this https://t.co/0l9FSGjTuD"

# %%
df <- twListToDF(tweets)
head(df)
# Out:
#   text
# 1 RT @DynamicWebPaige: The #rstats community is obsessed with:\n\n- straightforward documentation\n- effective communication\n- data visualizatio…
# 2 RT @hadleywickham: I've hung out with the data scientists at the BOE and I can highly recommend this opportunity! #rstats https://t.co/oZLA…
# 3 A representation of multiple GWAS results using #rstats and circos https://t.co/Ns9Wg646f3
# 4 RT @CedricGuerin: J'y étais hier et je recommande !!\nLa data c'est l'avenir pour le SEO !!\nhttps://t.co/S3jBEYxkNX\n#SEO #python #Rstats\nMer…
# 5 RT @Rbloggers: Love Machine: Automating the romantic songwriting process https://t.co/aiu49uI20I #rstats #DataScience
# 6 RT @R_Forwards: New blog post on initiatives in the #rstats community in Africa https://t.co/cbtI5NcUgU
#   favorited favoriteCount replyToSN created             truncated replyToSID
# 1 FALSE     0             NA        2018-02-12 22:11:13 FALSE     NA
# 2 FALSE     0             NA        2018-02-12 22:10:46 FALSE     NA
# 3 FALSE     0             NA        2018-02-12 22:10:38 FALSE     NA
# 4 FALSE     0             NA        2018-02-12 22:09:55 FALSE     NA
# 5 FALSE     0             NA        2018-02-12 22:09:34 FALSE     NA
# 6 FALSE     0             NA        2018-02-12 22:09:21 FALSE     NA
#   id                 replyToUID
# 1 963173674856611840 NA
# 2 963173561912512517 NA
# 3 963173527913287680 NA
# 4 963173348317519872 NA
# 5 963173259129782273 NA
# 6 963173204415086592 NA
#   statusSource
# 1 <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 2 <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 3 <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 4 <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 5 <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 6 <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
#   screenName      retweetCount isRetweet retweeted longitude latitude
# 1 brennanpcardiff 78            TRUE     FALSE     NA        NA
# 2 brennanpcardiff 19            TRUE     FALSE     NA        NA
# 3 R_Graph_Gallery  0           FALSE     FALSE     NA        NA
# 4 NinjaLinker      5            TRUE     FALSE     NA        NA
# 5 MangoTheCat      9            TRUE     FALSE     NA        NA
# 6 brennanpcardiff 11            TRUE     FALSE     NA        NA

# %%
sql_lite_file = tempfile()
register_sqlite_backend(sql_lite_file)
store_tweets_db(tweets)

# %%
from_db = load_tweets_db()
head(from_db)
# Out:
# [[1]]
# [1] "brennanpcardiff: RT @DynamicWebPaige: The #rstats community is obsessed with:\n\n- straightforward documentation\n- effective communication\n- data visualizatio…"
#
# [[2]]
# [1] "brennanpcardiff: RT @hadleywickham: I've hung out with the data scientists at the BOE and I can highly recommend this opportunity! #rstats https://t.co/oZLA…"
#
# [[3]]
# [1] "R_Graph_Gallery: A representation of multiple GWAS results using #rstats and circos https://t.co/Ns9Wg646f3"
#
# [[4]]
# [1] "NinjaLinker: RT @CedricGuerin: J'y étais hier et je recommande !!\nLa data c'est l'avenir pour le SEO !!\nhttps://t.co/S3jBEYxkNX\n#SEO #python #Rstats\nMer…"
#
# [[5]]
# [1] "MangoTheCat: RT @Rbloggers: Love Machine: Automating the romantic songwriting process https://t.co/aiu49uI20I #rstats #DataScience"
#
# [[6]]
# [1] "brennanpcardiff: RT @R_Forwards: New blog post on initiatives in the #rstats community in Africa https://t.co/cbtI5NcUgU"

# %%
cran_tweets <- userTimeline('cranatic')
cran_tweets[1:5]
# Out:
# [[1]]
# [1] "cranatic: Update: Bchron, BoolNet, caribou, CePa, fmri, HTSCluster, isa2, lessR, lgcp, spatstat. http://t.co/skyrajMA #rstats"
#
# [[2]]
# [1] "cranatic: New: extrafont, extrafontdb, Rttf2pt1, x12GUI. http://t.co/skyrajMA #rstats"
#
# [[3]]
# [1] "cranatic: Update: drc, RcmdrPlugin.survival, rrcov, spls. http://t.co/eEoXNifB #rstats"
#
# [[4]]
# [1] "cranatic: New: hzar. http://t.co/eEoXNifB #rstats"
#
# [[5]]
# [1] "cranatic: Update: directlabels, forensim, gdata, gWidgetstcltk, gWidgetsWWW, harvestr, rrlda, Rz, Sim.DiffProc, ... http://t.co/9JEe7K91 #rstats"

# %%
cran_tweets_large <- userTimeline('cranatic', n=100)
length(cran_tweets_large)
# Out:
# [1] 100

# %%
avail_trends = availableTrendLocations()
head(avail_trends)
# Out:
#   name      country woeid
# 1 Worldwide         1
# 2 Winnipeg  Canada  2972
# 3 Ottawa    Canada  3369
# 4 Quebec    Canada  3444
# 5 Montreal  Canada  3534
# 6 Toronto   Canada  4118

# %%
close_trends = closestTrendLocations(-42.8, -71.1)
head(close_trends)
# Out:
#   name       country woeid
# 1 Concepcion Chile   349860

# %%
trends = getTrends(2367105)
head(trends)
# Out:
#   name              url
# 1 #cleanenergy      http://twitter.com/search?q=%23cleanenergy
# 2 Paul Pierce       http://twitter.com/search?q=%22Paul+Pierce%22
# 3 #Beanpot          http://twitter.com/search?q=%23Beanpot
# 4 #MondayMotivation http://twitter.com/search?q=%23MondayMotivation
# 5 JUST ANNOUNCED    http://twitter.com/search?q=%22JUST+ANNOUNCED%22
# 6 #Olympics         http://twitter.com/search?q=%23Olympics
#   query                woeid
# 1 %23cleanenergy       2367105
# 2 %22Paul+Pierce%22    2367105
# 3 %23Beanpot           2367105
# 4 %23MondayMotivation  2367105
# 5 %22JUST+ANNOUNCED%22 2367105
# 6 %23Olympics          2367105

# %%
r_tweets <- searchTwitter("#rstats", n=300)
sources <- sapply(r_tweets, function(x) x$getStatusSource())
sources <- gsub("</a>", "", sources)
sources <- strsplit(sources, ">")
sources <- sapply(sources, function(x) ifelse(length(x) > 1, x[2], x[1]))
source_table = table(sources)
pie(source_table[source_table > 10])
# Out:
# plot without title
